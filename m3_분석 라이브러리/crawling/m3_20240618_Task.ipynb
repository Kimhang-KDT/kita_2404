# %% [markdown]
# Task1_0618. auto-mpg 데이터 셋에서 mpg와 weight의 선형 관계를 그래프로 작성하세요.(전체, origin에 따른 관계 2개 작성)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('drive/MyDrive/KDT_2404/m3_분석 라이브러리/dataset/auto-mpg.csv')

# %%
# origin에 따른 mpg와 weight의 선형 관계 그래프
plt.figure(figsize=(6,4))
sns.lmplot(data=df, x='mpg', y='weight', hue='origin')
plt.title('sns.Implot Example')
plt.show()

# 전체
plt.figure(figsize=(6,4))
sns.lmplot(data=df, x='mpg', y='weight')
plt.title('sns.Implot Example')
plt.show()

# %% [markdown]
# [Features]
# - species: 펭귄의 종 (Adelie, Chinstrap, Gentoo)
# - island: 데이터가 수집된 섬 (Biscoe, Dream, Torgersen)
# - bill_length_mm: 부리 길이 (mm)
# - bill_depth_mm: 부리 깊이 (mm)
# - flipper_length_mm: 지느러미 길이 (mm)
# - body_mass_g: 몸무게 (g)
# - sex: 성별 (male, female)
# - year: 데이터가 수집된 연도
#
# [Species]
# - Adelie: 아델리 펭귄
# - Chinstrap: 턱끈펭귄
# - Gentoo: 젠투펭귄
#
# [수집된 섬]
# - Biscoe
# - Dream
# - Torgersen

# %% [markdown]
# Task2_0618. pairplot을 생성하여 penguins 컬럼 간의 관계를 시각화 하세요. 단, 종(species)에 따라 다른 색상을 사용

# %%
df = sns.load_dataset('penguins')
#df.species.unique()
# bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g

sns.pairplot(df[df.columns], palette='rainbow',
             hue='species', diag_kind='kde')

# %% [markdown]
# Task3_0618. 펭귄 데이터셋을 사용하여, 각 종별로 섬(island)별 개체 수를 나타내는 카운트 플롯을 생성하세요. x축은 'island', hue는 'species'로 설정하세요.

# %%
plt.figure(figsize=(8,4))
sns.set_style('whitegrid')
sns.countplot(x='island', data=df, hue='species', palette='bone')
plt.title('Penguins Count Plot')
plt.show()

# %% [markdown]
# Task4_0618.sex와 class간의 생존율을 보여주는 히트맵을 작성하세요.

# %%
df = sns.load_dataset('titanic')

pivot = pd.pivot_table(df,index='sex',
                       columns='class',
                       values='survived',
                       aggfunc=(lambda x:x.sum()/x.count()), fill_value=0)

#df['sex'].replace({'male':0, 'female':1}, inplace=True)

sns.heatmap(pivot, annot=True, cmap='Pastel1')
plt.title('Heatmap of the Dataset', pad=20, fontsize=20)
# Out:
# Text(0.5, 1.0, 'Heatmap of the Dataset')

# %% [markdown]
# Task5_0618. 타이타닉 데이터셋을 사용하여, 객실 등급(class)에 따른 탑승객의 나이를 나타내는 박스 플롯과 바이올린 플롯을 같은 그래프 내에서 나란히 생성하세요. 이를 통해 각 클래스별 나이 분포의 차이를 비교하세요.

# %%
ttn = sns.load_dataset('titanic')
ttn['age'].replace(np.nan, ttn['age'].mean(), inplace=True)
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.boxplot(x=ttn['pclass'], y=ttn['age'], color='skyblue')

plt.subplot(1,2,2)
sns.violinplot(x=ttn['pclass'], y=ttn['age'], color='lightgreen')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %% [markdown]
# Task6_0618. 주어진 HTML 문서에서 모든 $<a>$ 태그를 추출하세요.

# %%
from bs4 import BeautifulSoup

html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a>
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>
</body></html>
"""

res = BeautifulSoup(html_doc, 'html.parser')

# %%
tags = res.find_all('a')
for tag in tags:
  print(tag)
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %% [markdown]
# Task7_0618. 주어진 HTML 문서에서 첫 번째 $<p>$ 태그의 텍스트를 추출하세요.

# %%
res.find('p').get_text()
# Out:
# "The Dormouse's story"

# %% [markdown]
# Task8_0618. 주어진 HTML 문서에서 모든 링크의 URL을 추출하세요.

# %%
links = res.find_all('a')
for link in links:
  print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %% [markdown]
# Task9_0618. 주어진 HTML 문서에서 클래스가 sister인 모든 태그를 추출하세요.

# %%
res.find_all(class_ = 'sister')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# Task10_0618. 주어진 HTML 문서에서 ID가 link1인 태그를 추출하세요

# %%
res.find(id='link1')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>]

# %% [markdown]
# Task11_0618. 주어진 HTML 문서에서 모든 텍스트를 추출하세요.

# %%
print(res.get_text())
# Out:
# The Dormouse's story
#
# The Dormouse's story
# Elsie
# Lacie
# Tillie

# %% [markdown]
# Task12_0618. 주어진 HTML 문서에서 href 속성이 http://example.com/lacie인 태그를 추출하세요.

# %%
res.select_one('a[href="http://example.com/lacie"]')
res.find(href='http://example.com/lacie')
# Out:
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>

# %% [markdown]
# Task13_0618. 주어진 HTML 문서에서 ID가 link1인 태그의 부모 태그를 추출하세요.

# %%
res.find(id='link1').parent.name
# Out:
# 'body'

# %% [markdown]
# Task14_0618. 주어진 HTML 문서에서 ID가 link1인 태그의 다음 형제 태그를 추출하세요.

# %%
res.find(id='link1').find_next_sibling()
# 앞의 형제 태그는 find_previous_sibling()
# Out:
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>

# %% [markdown]
# Task15_0618. 주어진 HTML 문서에서 ID가 link1인 태그의 href 속성 값을 추출하세요.

# %%
link = res.find(id='link1')
link.get('href')
# Out:
# http://example.com/elsie

# %%
# Out:
# <p> 태그의 부모 태그: body
# <a> 태그의 부모 태그: body
# <p> 태그와 <a> 태그는 형제 태그인가요? 예
