# %% [markdown]
# ## 프롬프트 엔지니어링
#
# 정의
# - Prompt engineering은 인공지능 모델, 특히 언어 모델에게 특정 작업을 수행하도록 지시하는 명령어(prompt)를 설계하고 조정하는 기술입니다.
# - 사용자는 명확하고 구체적인 질문이나 지시를 통해 모델이 원하는 결과를 생성하도록 유도할 수 있습니다. 이 과정은 자연어 처리에서 중요한 역할을 하며, 모델의 출력을 최적화하고 정확도를 높이는 데 기여합니다.
#
# 활용 분야
# - ChatGPT와 같은 대화형 AI, 자동화된 글쓰기, 고객 서비스, 교육, 코드 생성, 의료 데이터 분석 등 다양한 분야에서 prompt engineering이 활용됩니다.
# - 이를 통해 AI가 특정 요구 사항에 맞춘 결과를 생성하도록 하여, 작업 효율성을 높이고 사용자 경험을 향상시킬 수 있습니다.
#
# 사례들은 대규모 언어 모델(LLM)을 활용하는 다양한 방법을 보여줍니다. 각 사례는 특정 작업에 맞게 프롬프트를 설계하여 모델이 어떻게 유용한 결과를 생성하는지 설명합니다.
#
# - 텍스트 생성: 창의적인 글쓰기, 마케팅 카피 작성, 기술 문서 생성 등 다양한 분야에서 사용됩니다. 프롬프트의 구체성과 맥락 설정에 따라 생성되는 텍스트의 품질이 달라집니다.
#
# - 코드 생성 및 보완: 개발자가 원하는 코드 스니펫을 생성하거나 오류를 수정하는 데 도움을 줍니다. 예를 들어, 특정 함수나 알고리즘을 구현할 때 LLM을 활용해 코드를 제안받을 수 있습니다.
#
# - 데이터 분석 및 요약: 대량의 데이터를 요약하거나 분석 결과를 해석하는 데 유용합니다. LLM을 통해 데이터를 자연어로 쉽게 설명할 수 있어, 비전문가도 결과를 이해하기 쉽게 만듭니다.
#
# - 교육 및 학습 지원: 특정 주제에 대한 설명을 제공하거나, 학습 문제를 풀 때 힌트를 제시하는 방식으로 활용됩니다. 이는 교육용 도구나 학습 지원 시스템에서 유용하게 쓰일 수 있습니다.
#
# - 대화형 응용: 고객 서비스, 개인 비서 역할을 하는 챗봇 등에서 LLM이 활용됩니다. 사용자의 질문에 대해 신속하고 정확한 답변을 제공하며, 자연스러운 대화를 통해 사용자 경험을 향상시킵니다.
#
# - 창의적 작업 지원: 예술적 작업이나 새로운 아이디어를 생성할 때, 예를 들어 스토리라인 생성이나 음악 작곡 등에서 창의성을 발휘할 수 있도록 LLM이 도와줍니다.

# %% [markdown]
# ## 더 나은 결과를 얻기 위한 프롬프트 6가지 전략
# 대규모 언어 모델(때로는 GPT 모델이라고도 함)에서 더 나은 결과를 얻기 위한 프롬프트 전략과 전술. 여기에 설명된 방법은 더 큰 효과를 위해 때때로 조합하여 사용
#
# 명확하고 구체적인 언어 사용
# - 모호한 표현 대신 구체적 단어 사용: 일반적 표현보다 구체적인 단어를 사용하여 명확히 전달합니다. 예: "빠르다" 대신 "5분 내에".
# - 명확한 문장 구조 유지: 단문을 사용하여 문장이 복잡하지 않도록 합니다.
#
# 단계별 지침 제공
# - 작업 분할: 작업을 여러 단계로 나누어 각 단계를 명확히 설명합니다.
# - 단계별 결과 명시: 각 단계에서 기대되는 결과를 구체적으로 작성합니다.
#
# 필요한 컨텍스트 제공
# - 관련 배경 정보 포함: 작업을 이해하는 데 필요한 배경 정보를 제공합니다.
# - 구체적 시간/상황 명시: 언제 또는 어떤 상황에서 작업이 수행되는지 명시합니다.
#
# 예시 제공
# - 긍정적/부정적 예시 포함: 올바른 예시와 잘못된 예시를 모두 제공하여 비교할 수 있게 합니다.
# - 다양한 시나리오 제시: 다양한 상황에 대한 예시를 포함합니다.
#
# 부가 정보 제공
# - 추가 리소스 링크 제공: 참고할 수 있는 추가 자료나 링크를 제공합니다.
# - 참조 자료 목록화: 관련 자료들을 목록으로 정리하여 쉽게 접근할 수 있게 합니다.
#
# 피드백 및 조정
# - 피드백 요청: 지침의 명확성을 확인하기 위해 사용자로부터 피드백을 요청합니다.
# - 지침 조정: 받은 피드백을 반영하여 지침을 수정하고 개선합니다.

# %% [markdown]
# **명확하고 구체적인 언어 사용**
#
# 모호한 표현 대신 구체적 단어 사용
# - 모호한 표현: "빠르게 제출하세요."
# - 구체적 표현: "5분 내에 제출하세요."
#
# 모호한 표현인 "빠르게"는 사람마다 다르게 해석될 수 있습니다. 어떤 사람에게는 "빠르게"가 1시간을 의미할 수도 있고, 다른 사람에게는 몇 분을 의미할 수도 있습니다. 반면 "5분 내에"는 정확한 시간을 명시하여 모두가 같은 의미로 이해할 수 있게 합니다. 이를 통해 지침의 명확성이 높아져 오해가 줄어들고, 작업이 더 정확하게 수행될 수 있습니다.
#
# **명확한 문장 구조 유지**
# - 복잡한 문장: "프로젝트 파일을 검토하고, 오류를 수정하며, 다음 회의 전에 팀원들과 공유하세요."
# - 단순한 문장: "프로젝트 파일을 검토하세요. 오류를 수정하세요. 다음 회의 전에 팀원들과 공유하세요."
#
# 복잡한 문장은 여러 작업을 한 문장에 포함하여 읽는 사람이 이해하기 어렵게 만듭니다. 단순한 문장은 각 작업을 별도의 문장으로 분리하여 각 지시사항을 명확하게 전달합니다. 이를 통해 독자는 각 작업의 순서와 중요성을 쉽게 파악할 수 있으며, 오해나 실수를 줄일 수 있습니다.
#
# **작업 분할**
# - 복잡한 작업 지시: "보고서를 작성하고 검토한 후, 이메일로 보내세요."
# - 단계별 작업 지시:<br>
#   - 보고서 작성:
#     - 관련 데이터를 수집하세요.
#     - 수집한 데이터를 분석하여 요약하세요.
#     - 분석 결과를 바탕으로 보고서를 작성하세요.
#   - 보고서 검토:
#     - 작성한 보고서를 읽고 오류를 수정하세요.
#     - 팀원에게 보고서를 공유하고 피드백을 받으세요.
#
#   - 이메일로 전송:
#     - 검토한 보고서를 이메일에 첨부하세요.
#     - 적절한 수신자에게 이메일을 보내세요.
#
# 작업을 여러 단계로 분할하면 각 단계의 구체적인 작업이 명확해집니다. 이를 통해 사용자는 각 단계를 하나씩 완료하면서 전체 작업을 체계적으로 수행할 수 있습니다. 작업 분할은 복잡한 작업을 관리 가능하고 이해하기 쉽게 만듭니다.
#
# **단계별 결과 명시**
# - 작업 지시: 보고서를 작성하고 검토한 후, 이메일로 보내세요.
# - 단계별 결과 명시:
#   - 보고서 작성:
#     - 결과: 초안 보고서 완성. 데이터가 정확히 포함되어 있음.
#   - 보고서 검토:
#     - 결과: 오류가 수정된 보고서. 피드백이 반영됨.
#   - 이메일로 전송:
#     - 결과: 보고서가 이메일에 첨부되어 적절한 수신자에게 전송됨.
#
# 각 단계에서 기대되는 결과를 구체적으로 명시하면 사용자가 작업의 목표를 명확히 이해할 수 있습니다. 이를 통해 단계별로 작업의 완성도를 확인할 수 있고, 최종 결과물이 기대에 부합하는지 확인할 수 있습니다. 단계별 결과 명시는 작업의 명확성과 효율성을 높이는 데 중요한 역할을 합니다.
#
# **관련 배경 정보 포함**
# - 지시사항: "지난 주의 프로젝트 파일을 검토하세요."
# - 관련 배경 정보 포함:
#   - 프로젝트 개요:
#     - 배경 정보: "이 프로젝트는 고객 만족도 향상을 목표로 합니다. 지난 주 회의에서 고객 피드백을 분석하고, 이를 반영한 새로운 전략을 논의했습니다."
#   - 특정 파일 지시:
#     - 배경 정보: "지난 주에 작성된 '고객 피드백 분석 보고서'와 '전략 수정 제안서' 파일을 검토하세요. 이 파일들은 프로젝트 폴더의 '2024년 8월' 섹션에 있습니다."
#   - 검토 목적:
#     - 배경 정보: "이번 검토는 제안된 전략이 효과적인지 평가하고, 추가 개선 사항을 도출하는 것을 목표로 합니다."
#
# 작업을 이해하는 데 필요한 배경 정보를 제공하면 사용자가 작업의 목적과 맥락을 명확히 이해할 수 있습니다. 이로 인해 작업 수행의 정확성과 효율성이 높아집니다. 배경 정보는 작업의 중요성, 관련 문서 위치, 수행해야 할 구체적 내용 등을 포함할 수 있습니다.
#
# **구체적 시간/상황 명시**
# - 모호한 지시사항: "회의 전에 보고서를 작성하세요."
# - 구체적 지시사항:
#   - 시간 명시:
#     - 구체적 표현: "월요일 오전 9시 회의 전에 보고서를 작성하세요."
#     - 상황: "회의는 매주 월요일 오전 9시에 시작됩니다. 이 회의에서 이번 주 목표와 작업 분담이 논의될 예정입니다."
#   - 상황 명시:
#     - 구체적 표현: "월간 실적 검토 회의 전에, 이번 달 매출 보고서를 작성하세요."
#     - 상황: "월간 실적 검토 회의는 매월 마지막 금요일 오후 3시에 열립니다. 이 보고서는 전체 팀의 실적을 평가하는 데 사용됩니다."
#
# 구체적인 시간과 상황을 명시하면 작업의 시기와 맥락을 명확히 할 수 있습니다. 이는 사용자가 언제 작업을 완료해야 하는지 정확히 이해하게 하여, 일정 준수와 작업의 적시 수행을 도와줍니다. 또한, 작업의 중요성과 맥락을 이해함으로써, 더 나은 준비와 수행이 가능해집니다.
#
# **긍정적/부정적 예시 포함**
# - 지시사항: "이메일을 작성하세요."
# - 긍정적 예시:
#   - 제목: "회의 일정 확인 요청"
#   - 내용: "안녕하세요, 김 팀장님. 이번 주 금요일 오후 2시에 예정된 회의 일정을 확인하고자 합니다. 참석 가능하신지 알려주시면 감사하겠습니다. 감사합니다. 홍길동 드림."
# - 부정적 예시:
#   - 제목: "회의"
#   - 내용: "안녕하세요, 회의가 이번 주 금요일에 있을 것 같습니다. 참석할 수 있는지 알려주세요. 홍길동."
#
# 긍정적 예시와 부정적 예시를 제공하면 사용자는 무엇이 올바르고 무엇이 잘못된지 명확히 이해할 수 있습니다. 긍정적 예시는 최상의 결과를 보여주어 기대하는 바를 명확히 전달하며, 부정적 예시는 피해야 할 실수를 구체적으로 보여줍니다. 이를 통해 사용자는 지침을 더 잘 따르고, 결과물의 품질을 높일 수 있습니다.
#
# **다양한 시나리오 제시**
# - 지시사항: "보고서를 작성하세요."
# - 다양한 시나리오:
#   - 주간 보고서 작성:
#     - 상황: 매주 금요일마다 주간 업무 요약 보고서를 작성합니다.
#     - 포함 내용: 주요 성과, 문제점, 다음 주 계획.
#     - 긍정적 예시: "이번 주 주요 성과로는 판매 목표 120% 달성이 있습니다. - 문제점으로는 재고 부족이 있었으며, 이를 해결하기 위해 다음 주에는 재고 보충 계획을 세웠습니다."
#     - 부정적 예시: "이번 주에 여러 가지 일이 있었고, 다음 주에도 할 일이 많습니다."
#   - 프로젝트 보고서 작성:
#     - 상황: 프로젝트 마감 시 프로젝트 진행 상황과 결과를 요약한 보고서를 작성합니다.
#     - 포함 내용: 프로젝트 목표, 진행 상황, 최종 결과, 배운 점.
#     - 긍정적 예시: "프로젝트 목표는 고객 만족도 향상이었고, 진행 상황은 계획대로 진행되었습니다. 최종 결과로 고객 만족도가 20% 향상되었습니다. 배운 점은 초기 계획의 중요성입니다."
#     - 부정적 예시: "프로젝트가 끝났고, 결과가 나왔습니다."
#   - 연구 보고서 작성:
#     - 상황: 연구 프로젝트의 결과를 발표하기 위한 보고서를 작성합니다.
#     - 포함 내용: 연구 목적, 방법, 결과, 결론.
#     - 긍정적 예시: "연구 목적은 새로운 항생제의 효과를 검증하는 것이었습니다. 실험 방법은 무작위 대조 실험이었고, 결과는 긍정적이었습니다. 결론은 새로운 항생제가 효과적이라는 것입니다."
#     - 부정적 예시: "연구를 했고, 결과가 좋았습니다."
#
# 다양한 시나리오를 제시하면 사용자는 각 상황에 맞게 작업을 어떻게 수행해야 하는지 명확히 이해할 수 있습니다. 각 시나리오의 구체적인 예시를 통해, 사용자는 자신이 직면한 상황에 적합한 지침을 적용할 수 있으며, 기대되는 결과물의 기준을 명확히 알 수 있습니다.
#
# **추가 리소스 링크 제공 및 참조 자료 목록화**
# - 지시사항: "보고서를 작성하기 위한 참고 자료를 확인하세요."
# - 추가 리소스 링크 제공:
#   - 링크 1: 보고서 작성 가이드라인
#   - 링크 2: 데이터 분석 기법
#   - 링크 3: 피드백 수집 방법
# - 참조 자료 목록화:
#   - 보고서 작성 가이드라인:
#     - 내용: 보고서의 구조, 형식, 필수 요소에 대한 상세 지침
#     - 링크: 보고서 작성 가이드라인
#   - 데이터 분석 기법:
#     - 내용: 데이터를 효과적으로 분석하는 방법과 도구
#     - 링크: 데이터 분석 기법
#   - 피드백 수집 방법:
#     - 내용: 피드백을 효과적으로 수집하고 활용하는 방법
#     - 링크: 피드백 수집 방법
#
# 추가 리소스 링크를 제공하면 사용자는 필요한 정보를 쉽게 찾아볼 수 있습니다. 참조 자료를 목록화하면 관련 자료를 체계적으로 정리하여 사용자가 필요할 때 빠르게 접근할 수 있게 도와줍니다. 이는 작업의 정확성과 효율성을 높이는 데 매우 유용합니다.
#
# **피드백 요청**
# - 지시사항: "보고서를 작성한 후, 제출하세요."
# - 피드백 요청 추가:
#   - 초안 제출:
#     - 지시사항: "보고서 초안을 작성한 후, 팀원들에게 공유하세요."
#     - 피드백 요청: "초안에 대한 피드백을 받으세요. 피드백을 바탕으로 수정 사항을 반영하세요."
#   - 최종본 제출:
#     - 지시사항: "피드백을 반영한 최종 보고서를 작성한 후, 제출하세요."
#     - 피드백 요청: "제출 전, 팀원 또는 관리자에게 최종 확인을 요청하세요. 보고서의 명확성과 완성도를 높이기 위해 피드백을 활용하세요."
#
# 피드백 요청을 통해 지침의 명확성을 확인하고 개선할 수 있습니다. 사용자로부터 피드백을 받으면, 지침이 제대로 이해되고 있는지 확인할 수 있으며, 필요한 경우 수정하여 더 명확하고 효과적인 지침을 제공할 수 있습니다. 이를 통해 작업의 품질과 정확성을 높일 수 있습니다.
#
# **지침 조정**
# - 초기 지침:
# "프로젝트 계획서를 작성하세요."
# - 피드백:
#   - "계획서에 포함해야 할 세부 항목이 명확하지 않습니다."
#   - "완료 기한이 명시되지 않아 혼란스럽습니다."
# - 수정된 지침:
#   - 프로젝트 계획서 작성:
#     - 포함 항목:
#       - 프로젝트 개요
#       - 목표 및 기대 성과
#       - 주요 단계 및 일정
#       - 필요한 자원
#     - 완료 기한:
#       - "다음 주 금요일 오후 5시까지 제출하세요."
#
# 피드백을 반영하여 지침을 수정하면, 지침의 명확성과 효과성이 개선됩니다. 사용자가 작업을 더 정확하고 효율적으로 수행할 수 있도록 도와줍니다. 피드백을 통해 지침의 문제점을 파악하고, 구체적이고 명확한 지침으로 수정하는 과정이 중요합니다.

# %%
# %pip install -q openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.6 MB/s eta 0:00:00

# %%
from openai import OpenAI
client = OpenAI(api_key='')

completion = client.chat.completions.create(
    model = 'gpt-4o-mini-2024-07-18',
    messages = [
        {"role":"system","content":"당신은 AI 모델 개발자이다."},
        {"role":"user","content":"LLM에 대해 설명해줘."}
    ]
)
#print(completion)
print(completion.choices[0].message.content)
# Out:
# LLM은 "Large Language Model"의 약자로, 대규모 언어 모델을 의미합니다. 이러한 모델은 자연어 처리(NLP) 분야에서 많은 데이터에 기반하여 훈련된 인공지능 시스템으로, 인간의 언어를 이해하고 생성하는 능력을 가지고 있습니다.
#
# ### LLM의 주요 특징:
#
# 1. **대규모 데이터 활용**: LLM은 일반적으로 텍스트 데이터로 구성된 대규모 데이터셋으로 훈련됩니다. 이는 뉴스, 소설, 웹사이트, 위키피디아 등 다양한 출처에서 수집된 데이터입니다.
#
# 2. **딥러닝 아키텍처**: LLM은 주로 딥러닝 기술, 특히 신경망 구조인 Transformer를 기반으로 합니다. 이 아키텍처는 문맥을 이해하고 장기적인 의존성을 처리하는 데 효과적입니다.
#
# 3. **사전 훈련 및 미세 조정**: LLM은 일반적인 언어 패턴을 학습하기 위해 사전 훈련(pre-training) 단계에서 대량의 텍스트 데이터로 훈련되고, 특정 태스크에 맞추어 미세 조정(fine-tuning)될 수 있습니다.
#
# 4. **자연어 생성**: LLM은 질문에 답하거나, 텍스트를 요약하거나, 새로운 텍스트를 생성하는 등 다양한 작업을 수행할 수 있습니다.
#
# 5. **응용 분야**: LLM은 챗봇, 자동 번역, 콘텐츠 생성, 요약 및 텍스트 분석 등 여러 분야에서 활용되고 있습니다.
#
# 6. **컨텍스트 이해**: LLM은 주어진 입력에 대한 응답을 생성할 때 문맥을 고려하여 자연스럽고 일관성 있는 텍스트를 생성할 수 있습니다.
#
# ### 한계와 도전 과제:
#
# - **편향**: LLM은 훈련 데이터의 편향을 반영할 수 있으며, 이는 비윤리적이거나 부적절한 콘텐츠 생성을 초래할 수 있습니다.
# - **해석 가능성**: 대규모 모델은 종종 블랙박스처럼 작동하여 결과의 근거를 이해하기 어려운 경우가 많습니다.
# - **상황 제약**: LLM은 최신 정보에 대한 접근이 제한적이며, 훈련 시 데이터에 포함되지 않은 정보에 대한 이해도가 부족할 수 있습니다.
#
# 결론적으로, LLM은 강력한 언어 처리 도구로, 다양한 실생활의 문제들을 해결하는 데 기여하고 있지만, 그 사용과 관련된 윤리적 고려사항이 필요합니다.

# %% [markdown]
# #### 명확성과 구체성
#
# - 특정 주제에 대해 글을 작성하도록 요청할 때

# %%
from openai import OpenAI

# 명확하고 구체적인 프롬프트
prompt = "재생 가능 에너지원이 지구 온난화를 줄이는 데 기여하는 이점에 대해 간결한 단락으로 설명해 주세요."

completion = client.chat.completions.create(
    model = 'gpt-4o-mini-2024-07-18',
    messages = [
        {"role":"system","content":"당신은 환경문제를 연구하는 과학자이다."},
        {"role":"user","content":prompt}
    ]
)

print(completion.choices[0].message.content)

# %%
from openai import OpenAI

# 명확하고 구체적인 프롬프트
prompt = ("다음 맥락을 고려하여 설명해주세요: '최근 미국 대선이 진행중입니다.'"
          "후보자들의 공략이 한국 경제에 미칠 영향을 분석해주세요'"
)
completion = client.chat.completions.create(
    model = 'gpt-4o-mini-2024-07-18',
    messages = [
        {"role":"system","content":"당신은 경제 전문가이다."},
        {"role":"user","content":prompt}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 미국 대선이 진행 중이라는 상황은 한국 경제에 여러 가지 방식으로 영향을 미칠 수 있습니다. 미국은 한국의 주요 무역 파트너이자 외교적 동맹국이기 때문에 미국의 정치적 변화는 한국 경제에 중요한 의미를 갖습니다. 다음은 후보자들의 공약이 한국 경제에 미칠 수 있는 영향에 대한 몇 가지 분석입니다.
#
# 1. **무역 정책**: 후보자들이 제시하는 무역 정책은 한국 경제에 직접적인 영향을 미칠 수 있습니다. 만약 후보자가 보호무역주의를 강화할 경우, 한국의 수출 주도형 경제에 부정적인 영향을 줄 수 있습니다. 단기적으로는 무역 마찰이 증가할 수 있으며, 이는 한국의 주요 산업에 타격을 줄 수 있습니다. 반면, 자유무역을 지지하는 후보자가 당선될 경우, 한국과의 무역 협력이 더 강화될 수 있습니다.
#
# 2. **기술 및 산업 정책**: 미국의 기술 정책이나 반도체 산업 관련 공약은 한국의 주요 산업에도 큰 영향을 미칠 수 있습니다. 예를 들어, 반도체, 바이오 헬스 등 전략 산업에 대한 투자와 지원이 강조된다면, 한국의 관련 기업들도 긍정적인 영향을 받을 수 있습니다. 반대로, 미국 자체의 기술 보호 조치가 강화될 경우 한국 기업의 미국 시장 진입이 어려워질 수 있습니다.
#
# 3. **외교 정책**: 미국의 외교 정책 방향이 바뀌면 한국의 안보 및 외교적 입장에도 변화가 올 수 있습니다. 예를 들어, 미국과 중국의 갈등이 심화될 경우, 한국은 중립적인 외교 자세를 유지하기 어려워질 수 있으며, 이는 경제적 불확실성을 증가시킬 수 있습니다. 또한, 한국과 미국 간의 국방비 분담 문제나 주한 미군 문제도 경제에 영향을 미칠 수 있습니다.
#
# 4. **환율 및 자본 흐름**: 미국 대선이 진행되면서 금융시장에서의 변동성이 증가할 수 있습니다. 이는 환율, 특히 원화의 달러 대비 가치에 영향을 미칠 수 있으며, 결과적으로 수출입 가격과 해외 투자에 영향을 줄 수 있습니다. 후보자의 경제 정책에 따라 달러 강세나 약세가 발생할 수 있으며, 이는 한국 기업들의 경쟁력에 영향을 미칠 수 있습니다.
#
# 5. **경제 성장률**: 미국 경제의 성장률은 한국 경제에 직간접적으로 영향을 미치므로, 후보자들이 제시하는 경제 성장 전략이나 재정 정책이 중요한 요소가 될 것입니다. 미국이 강한 성장을 이룬다면 한국의 수출에도 긍정적인 영향을 미칠 수 있습니다.
#
# 결론적으로, 미국 대선은 한국 경제에 다양한 방식으로 영향을 미칠 수 있으며, 후보자들의 공약과 정책 방향에 따라 그 파급 효과는 크게 달라질 것입니다. 한국 정부와 기업들은 이러한 변화에 발빠르게 대응할 필요가 있습니다.

# %%
prompts = [
    "정기적인 운동의 건강상의 이점은 무엇인가요?",
    "정기적으로 운동을 하는 것의 장점을 설명해 주세요.",
    "정기적인 신체 활동이 건강에 어떤 영향을 미치나요?"
]

for prompt in prompts:
  completion = client.chat.completions.create(
      model = 'gpt-4o-mini-2024-07-18',
      messages = [
          {"role":"system","content":"당신은 건강관리 전문가이다."},
          {"role":"user","content":prompt}
      ]
  )
  print(f"프롬프트: {prompt}")
  print(completion.choices[0].message.content)
  print("\n"+"="*100+"\n")

# %% [markdown]
# Task1_0812. Prompt engineering 6개 전략의 각 전술을 적용하여 10개의 사례를 작성하세요.

# %%
# 피드백 요청

from openai import OpenAI

client = OpenAI(api_key='')

prompts = [
    "결혼식에 초대하는 초대장을 작성하세요.",
    "초안에 대한 피드백을 받으세요. 피드백을 바탕으로 수정 사항을 반영하세요.",
    "피드백을 반영한 초대장을 작성하세요.",
    "초대장을 초대객들에게 발송하기 전에 팀원 및 관리자에게 최종 확인을 요청하세요."
]

# 새로운 피드백 프롬프트 추가
feedback_prompt = "초안에 대해 팀원이 피드백을 제공하였습니다. 피드백을 반영하여 초안을 수정하세요."

for prompt in prompts:
    # 최초의 응답 생성
    completion = client.chat.completions.create(
        model = 'gpt-4o-mini-2024-07-18',
        messages = [
            {"role":"system","content":"당신은 웨딩 플래너이다."},
            {"role":"user","content":prompt}
        ]
    )
    print(f"프롬프트: {prompt}")
    initial_response = completion.choices[0].message.content
    print(initial_response)

    # 피드백을 추가 요청하는 부분
    if "피드백" in prompt:
        completion_feedback = client.chat.completions.create(
            model = 'gpt-4o-mini-2024-07-18',
            messages = [
                {"role":"system","content":"당신은 웨딩 플래너이다."},
                {"role":"user","content":feedback_prompt},
                {"role":"assistant","content":initial_response}
            ]
        )
        feedback_response = completion_feedback.choices[0].message.content
        print("\n[피드백 반영 후 결과]")
        print(feedback_response)

    print("\n" + "="*100 + "\n")
# Out:
# 프롬프트: 결혼식에 초대하는 초대장을 작성하세요.
# 물론입니다! 아래는 결혼식 초대장 예시입니다:
#
# ---
#
# **결혼식 초대장**
#
# 사랑하는 ______(신랑 이름)와 ______(신부 이름)의 결혼식에 초대합니다.
#
# 두 사람의 사랑이 하나의 행사가 되는 날,
# 가족과 친구들과 함께 소중한 순간을 나누고자 합니다.
#
# **일시:**
# 날짜: 2023년 __월 __일 (토요일)
# 시간: 오후 __시
#
# **장소:**
# ______ (예식 장소 이름)
# 주소: _____________
#
# 함께해 주셔서 우리의 사랑의 시작을 축복해 주세요.
# 여러분의 소중한 참석을 기다립니다.
#
# **신랑 측 연락처:** ____ (연락처)
# **신부 측 연락처:** ____ (연락처)
#
# 감사합니다.
# ______ (신랑 이름) & ______ (신부 이름)
#
# ---
#
# 초대장에 맞는 세부정보를 넣어 수정해 주시면 됩니다! 필요에 따라 다른 스타일이나 포맷으로도 도와드릴 수 있으니 말씀해 주세요.
#
# ====================================================================================================
#
# 프롬프트: 초안에 대한 피드백을 받으세요. 피드백을 바탕으로 수정 사항을 반영하세요.
# 물론입니다! 초안을 공유해 주시면 피드백을 드리고, 그에 기반하여 수정할 사항을 제안해 드리겠습니다. 초안을 부탁드립니다.
#
# [피드백 반영 후 결과]
# 피드백 내용을 공유해 주시면 수정할 수 있도록 도와드리겠습니다. 초안과 피드백을 알려주세요.
#
# ====================================================================================================
#
# 프롬프트: 피드백을 반영한 초대장을 작성하세요.
# 초대장 작성 시 피드백을 반영하는 것은 매우 중요합니다. 아래에 예시로 간단한 웨딩 초대장을 작성해 보았습니다.
#
# ---
#
# **[신랑 이름] & [신부 이름]의 웨딩 초대장**
#
# 사랑하는 가족과 친구 여러분,
#
# 우리는 두 사람의 사랑을 맺는 특별한 날에 여러분을 초대합니다.
#
# 📅 **날짜:** [결혼식 날짜]
# 🕗 **시간:** [시간]
# 📍 **장소:** [결혼식 장소]
#
# 사랑의 여정을 함께할 소중한 순간에 여러분과 함께하고 싶습니다. 저희의 행복한 시작을 축복해 주시길 바랍니다.
#
# **Dress Code:** [드레스 코드, 예: 포멀, 캐주얼 등]
# **RSVP:** [답변 기한과 방법]
#
# 여러분의 소중한 시간이 함께 하기를 기대합니다.
#
# 사랑을 담아,
# [신랑 이름] & [신부 이름]
#
# ---
#
# 위의 템플릿을 기반으로 필요한 세부사항을 추가하거나 수정하시면 됩니다. 피드백에 따라 초대장을 개성 있게 꾸미는 것도 좋습니다!
#
# [피드백 반영 후 결과]
# 초안에 대해 팀원의 피드백을 반영하여 수정해보겠습니다. 아래는 수정된 웨딩 초대장 예시입니다.
#
# ---
#
# **[신랑 이름] & [신부 이름]의 웨딩 초대장**
#
# 사랑하는 가족과 친구 여러분,
#
# 저희는 서로의 사랑을 약속하고, 새 출발을 함께하는 특별한 날에 여러분을 초대합니다.
#
# 📅 **날짜:** [결혼식 날짜]
# 🕗 **시간:** [결혼식 시작 시간]
# 📍 **장소:** [결혼식 장소]
# (주소 및 주차 정보 포함)
#
# 여러분과 함께 이 소중한 순간을 나누고 싶습니다. 저희의 행복한 결혼식에 꼭 함께 해주시면 감사하겠습니다.
#
# **Dress Code:** [예: 포멀, 세미 포멀, 캐주얼 등]
# **RSVP:** [답변 기한 및 방법, 예: 이메일/전화번호]
#
# 여러분의 따뜻한 축복과 사랑을 기다립니다.
#
# 사랑을 담아,
# [신랑 이름] & [신부 이름]
#
# ---
#
# 이 초안은 팀원의 피드백을 반영하여 더욱 구체적이고 초대받는 이가 이해하기 쉬운 형식으로 수정되었습니다. 필요한 세부사항을 추가하거나 조정하시고, 각 요소를 개인화하여 더욱 특별하게 만드시면 좋겠습니다!
#
# ====================================================================================================
#
# 프롬프트: 초대장을 초대객들에게 발송하기 전에 팀원 및 관리자에게 최종 확인을 요청하세요.
# 안녕하세요, 팀원 및 관리자 여러분.
#
# 우리가 준비한 웨딩 초대장이 이제 거의 완성되었습니다. 초대장을 초대객들에게 발송하기 전에, 최종 확인을 요청드립니다.
#
# 아래의 사항을 체크해주시기 바랍니다:
#
# 1. **초대장 디자인**: 디자인이 모든 정보와 함께 일관되게 표현되었는지 확인해 주세요.
# 2. **일정 및 장소**: 결혼식 일시 및 장소가 정확하게 기재되었는지 확인해 주세요.
# 3. **RSVP 정보**: 답장을 요청하는 기한 및 방법이 명확하게 기재되어 있는지 확인해 주세요.
# 4. **특별 요청사항**: 특별한 요구나 알림이 필요하다면, 해당 정보가 초대장에 포함되었는지 확인해 주세요.
#
# 최종 확인 결과를 [기한]까지 회신해 주시면 감사하겠습니다. 여러분의 피드백이 매우 중요하니, 빠짐없이 확인해주시기 바랍니다.
#
# 고맙습니다!
#
# [당신의 이름]
# [당신의 직함]
# [웨딩 플래너 회사명]
#
# ====================================================================================================

# %%
user_prompts = [
    """월화 근무였고 9개월 다녔습니다
    저번주부터 제 타임에 다른알바가 와있어서 점장님한테 전화했더니 원래 이번주만 안나오는건데 말을 안해줬다고 미안하다 그러더군요
    그래서 제가 저 이번주는(12,13) 나오는거맞냐고 물어보니 그렇다고 하셨어요
    근데 일요일에 갑자기 카톡으로 해고 통보를 받아서 현재 출근을 못하는 상태입니다
    부당해고 수당 받아낼수 있을까요? 편의점에 알바만 20명입니다 또 부당해고수당을 받으면 얼마정도 나오는건가요?"""
]

sys_prompt = """
**당신은 공인 노무사입니다.**
1. 근로기준 고용, 급여와 같은 노동 법률 질문일 경우, 법률 조항을 언급하며 자세히 답변해주세요.
2. 고용 노동 행정과 관련한 정책 및 제도 문의일 경우, 한국의 고용 노동 정책과 관련된 정보를 언급하며 자세히 답변해주세요.
"""

for prompt in user_prompts:
  completion = client.chat.completions.create(
      model = 'gpt-4o-mini-2024-07-18',
      messages = [
          {"role":"system","content":sys_prompt},
          {"role":"user","content":prompt}
      ]
  )
  print(f"프롬프트: {prompt}")
  print(completion.choices[0].message.content)
  print("\n"+"="*100+"\n")
# Out:
# 프롬프트: 월화 근무였고 9개월 다녔습니다
#     저번주부터 제 타임에 다른알바가 와있어서 점장님한테 전화했더니 원래 이번주만 안나오는건데 말을 안해줬다고 미안하다 그러더군요
#     그래서 제가 저 이번주는(12,13) 나오는거맞냐고 물어보니 그렇다고 하셨어요
#     근데 일요일에 갑자기 카톡으로 해고 통보를 받아서 현재 출근을 못하는 상태입니다
#     부당해고 수당 받아낼수 있을까요? 편의점에 알바만 20명입니다 또 부당해고수당을 받으면 얼마정도 나오는건가요?
# 근로기준법에 따르면, 근로자의 해고는 정당한 사유가 있을 경우에만 가능하며, 정당한 사유 없이 해고된 경우에는 "부당해고"에 해당합니다. 본인의 경우에는 근무 재배치 후 해고 통보를 받으신 것으로 보이는데, 이러한 상황에서 부당해고로 주장할 수 있는 근거가 있을 수 있습니다.
#
# 근로기준법 제23조에 따르면, 사용자는 근로자를 해고할 경우 정당한 사유를 제공해야 하며, 해고 통보는 최소한 30일 이전에 해야 합니다(단, 3개월 미만의 근로자에게는 3일 전 통보). 따라서, 만약 점장님이 아무런 사유를 제시하지 않고 해고를 통보한 경우에는 부당해고로 판단될 수 있습니다.
#
# 1. **부당해고수당 청구 가능성**: 부당해고가 이루어진 경우, 근로자는 해고일로부터 3년 이내에 부당해고 구제신청을 노동위원회에 할 수 있습니다. 구제신청이 받아들여질 경우, 원직 복직 또는 해고 당시의 임금에 해당하는 금액을 요구할 수 있습니다.
#
# 2. **수당 금액**: 부당해고 수당의 금액은 해고 전의 평균 임금을 기준으로 계산됩니다. 만약 주당 근무시간과 시급을 기반으로 월급을 계산하여 해고된 기간까지의 임금을 청구할 수 있습니다. 예를 들어, 주당 12시간 근무하고 시급이 10,000원이었을 경우, 월급은 약 480,000원이 될 것입니다. 이 금액을 바탕으로 구체적인 지급액을 산출할 수 있습니다.
#
# 따라서, 부당해고가 인정된다면 원직 복귀 혹은 해고 기간에 대한 임금 보상을 청구하실 수 있습니다. 이와 관련하여 구체적인 상황이 필요하다면, 노동위원회에 상담하시거나 법률 전문가와 상담하시는 것을 권장합니다.
#
# ====================================================================================================

# %% [markdown]
# 예시 사용
#
# - 특정 형식의 응답을 요청할 때

# %%
prompt = (
    "숫자의 팩토리얼ㅇ르 계산하는 파이썬 함수를 작성해 주세요."
    "예시:\n"
    "입력: 5\n"
    "출력: 120\n"
    "함수 코드:"
)

completion = client.chat.completions.create(
    model = 'gpt-4o-mini-2024-07-18',
    messages = [
        {"role":"system","content":"당신은 파이썬 코딩을 가르 치는 코딩튜터이다."},
        {"role":"user","content":prompt}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 팩토리얼을 계산하는 파이썬 함수를 작성해드리겠습니다. 아래의 코드는 주어진 숫자의 팩토리얼을 계산하는 함수입니다.
#
# ```python
# def factorial(n):
#     if n < 0:
#         return "음수의 팩토리얼은 정의되지 않습니다."
#     elif n == 0 or n == 1:
#         return 1
#     else:
#         result = 1
#         for i in range(2, n + 1):
#             result *= i
#         return result
#
# # 예시 사용
# print(factorial(5))  # 출력: 120
# ```
#
# 위 함수는 `factorial`이라는 이름을 가지고 있으며, `n`이라는 매개변수를 입력받습니다. 음수일 경우에는 계산이 불가능하다는 메시지를 반환하고, 0이나 1일 경우에는 1을 반환합니다. 그 외의 경우에는 반복문을 통해 팩토리얼을 계산합니다.

# %% [markdown]
# 지시 관리
# - 응답 형식과 길이를 명확히 지시

# %%
prompt = """다음 텍스트의 주요 포인트를 50자 이내로 요약해 주세요:
인공지능(AI)은 다양한 산업에서 급속히 성장하는 분야로, 업무 자동화, 데이터 분석을 통한 인사이트 제공,
개인 맞춤형 추천을 통한 고객 경험 향상 등의 응용 분야가 있습니다."""

completion = client.chat.completions.create(
    model = 'gpt-4o-mini-2024-07-18',
    messages = [
        {"role":"system","content":"당신은 인공지능을 학습하는 대학원생이다."},
        {"role":"user","content":prompt}
    ]
)

print(completion.choices[0].message.content)
#
# Out:
# 인공지능은 산업 성장을 이끄는 자동화, 데이터 분석, 맞춤 추천에 활용됩니다.

# %% [markdown]
# ### 문법 교정

# %%
response = client.chat.completions.create(
    model='gpt-4o-mini-2024-07-18',
    messages = [
        {
            "role": "system",
            "content": "You will be provided with statements, and your task is to convert them to standard English."
        },
        {
            "role": "user",
            "content": "She no went to the market."
        }
    ],
    temperature=0.7,
    max_tokens=64,
    top_p=1
)

print(response.choices[0].message.content)
# Out:
# She didn't go to the market.

# %%
prompt = """
최근에 발견된 행성 구크룩스에서 발견된 과일이 많이 있습니다. 거기에는 보라색이고 사탕 맛이 나는 네오스키즐이 자랍니다.
또한 칙칙한 파란색 과일인 로헤클도 있는데, 레몬과 비슷한 매우 신맛이 납니다. 포우닛은 밝은 녹색이고 단맛보다는 짭짤함이 더 강합니다.
네온 핑크 맛이며 솜사탕 맛이 나는 루프노바도 많이 있습니다. 마지막으로 글로울이라는 과일이 있는데,
매우 신맛이 나고 쓴맛이 나는 산성이고 부식성이 있으며 옅은 오렌지색을 띱니다.
"""

response = client.chat.completions.create(
    model='gpt-4o-mini-2024-07-18',
    messages = [
        {
            "role": "system",
            "content": "구조화 되지 않은 데이터가 제공되면 이를 CSV 형식을 구문 분석하는 것이 여러분의 과제입니다."
        },
        {
            "role": "user",
            "content": prompt
        }
    ],
    temperature=0.7,
    max_tokens=300,
    top_p=1
)

3print(response.choices[0].message.content)
# Out:
# 아래는 제공된 데이터를 CSV 형식으로 구문 분석한 것입니다.
#
# ```csv
# 과일명,색상,맛
# 네오스키즐,보라색,사탕 맛
# 로헤클,칙칙한 파란색,신맛
# 포우닛,밝은 녹색,짭짤함
# 루프노바,네온 핑크,솜사탕 맛
# 글로울,옅은 오렌지색,신맛과 쓴맛
# ```
#
# 위와 같이 과일의 이름, 색상, 맛 정보를 구조화된 형태로 정리했습니다.
